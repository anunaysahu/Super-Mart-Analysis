# %% [markdown]
# ## Anunay Sahu
#
# # Data Science and Business Analytics
#
#
# #### Exploratory Data Analysis - Retail
# ####  Perform ‘Exploratory Data Analysis’ on dataset ‘SampleSuperstore’
# ####   As a business manager, try to find out the weak areas where you can work to make more profit.
# ####  What all business problems you can derive by exploring the data?

# %% [markdown]
# # What is Exploratory Data Analysis(EDA)?

# %% [raw]
# We want to explain EDA in simple terms, it means trying to understand the given data much better, so that we can make some sense out of it.

# %% [markdown]
# #### In statistics, exploratory data analysis is an approach to analyzing data sets to summarize their main characteristics, often with visual methods. A statistical model can be used or not, but primarily EDA is for seeing what the data can tell us beyond the formal modeling or hypothesis testing task.

# %% [raw]
# EDA in Python uses data visualization to draw meaningful patterns and insights.
# It also involves the preparation of data sets for analysis by removing irregularities in the data.

# %% [markdown]
# ### The very first step of EDA is Data Sourcing, we have seen how we can access data and load into our system.

# %% [markdown]
# ## 1. Data Sourcing
# ### Data Sourcing is the process of finding and loading the data into our system. Broadly there are two ways in which we can find data.
# ## Private Data
# #### As the name suggests, private data is given by private organizations. There are some security and privacy concerns attached to it. This type of data is used for mainly organizations internal analysis.
# ## Public Data
# #### This type of Data is available to everyone. We can find this in government websites and public organizations etc. Anyone can access this data, we do not need any special permissions or approval.

# %%
#importing all the libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
mydataset=pd.read_csv(r"A:\MCA VI Sem\April Report 2021\Projects\S S\Task 3 - Exploratory-Data-Analysis---Retail/SampleSuperstore.csv") #loading dataset....
mydataset.head()  #getting head of the data set where by default 5 values would be visible starting from 0.
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
mydataset.info() #getting information of dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# ## 2. Data Cleaning
# ### After completing the Data Sourcing, the next step in the process of EDA is Data Cleaning. It is very important to get rid of the irregularities and clean the data after sourcing it into our system. Irregularities are of different types of data.
# #### Missing Values
# #### Incorrect Format
# #### Incorrect Headers
# #### Anomalies/Outliers

# %%
mydataset.isnull().sum() #to check null/missing values in dataset
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
mydataset.columns # coloumns name
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
mydataset.shape  #shape of dataset
# Out:
# (9994, 13)

# %%
mydataset.nunique() #return distinct entries in particular coloumns
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
#drop unwanted rows from dataset
dt=mydataset.drop(['Postal Code'],axis=1)
dt.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#   Region         Category Sub-Category     Sales  Quantity  Discount    Profit
# 0  South        Furniture    Bookcases  261.9600         2      0.00   41.9136
# 1  South        Furniture       Chairs  731.9400         3      0.00  219.5820
# 2   West  Office Supplies       Labels   14.6200         2      0.00    6.8714
# 3  South        Furniture       Tables  957.5775         5      0.45 -383.0310
# 4  South  Office Supplies      Storage   22.3680         2      0.20    2.5164

# %% [markdown]
# #  3. Exploratory Data Analysis

# %%
plt.figure(figsize=(10,7))
sns.kdeplot(dt['Sales'],color='red',label='Sales',shade=True,bw=4)
sns.kdeplot(dt['Profit'],color='Blue',label='Profit',shade=True,bw=4)
plt.xlim([-1000,10000])
plt.title('Profit and Sales Graph',fontsize=25)
plt.show()
#plt.legend()

# %% [markdown]
# Profit is more than that of sale but there are some areas where profit could be increased.

# %% [markdown]
# # Countplot for each Column

# %%
fig,axs=plt.subplots(nrows=2,ncols=2,figsize=(10,7));
sns.countplot(dt['Category'],ax=axs[0][0])
axs[0][0].set_title('Category',fontsize=20)
sns.countplot(dt['Segment'],ax=axs[0][1])
sns.countplot(dt['Ship Mode'],ax=axs[1][0])
sns.countplot(dt['Region'],ax=axs[1][1])
axs[0][1].set_title('Segment',fontsize=20)
axs[1][0].set_title('Ship Mode',fontsize=20)
axs[1][1].set_title('Region',fontsize=20)
plt.tight_layout()

# %% [markdown]
# ## Analysis using Pairplot of each column
#
# #### [1] Based on the Category

# %%
sns.pairplot(dt,hue='Category')

# %% [markdown]
# #### [2] Based on Region

# %%
sns.pairplot(dt,hue='Region')

# %% [markdown]
# #### [3] Based on the Segment

# %%
sns.pairplot(dt,hue='Segment')

# %%
dt.corr()  #getting the correlation of the data set
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200795 -0.028190  0.479064
# Quantity  0.200795  1.000000  0.008623  0.066253
# Discount -0.028190  0.008623  1.000000 -0.219487
# Profit    0.479064  0.066253 -0.219487  1.000000

# %% [markdown]
# ## Heatmap for correlation
#
# ### What is a Heatmap?
# #### A heat map is a data visualization technique that shows magnitude of a phenomenon as color in two dimensions.

# %%
# Heatmap to check the collinearity between sales, quantity, discount and profit
plt.figure(figsize=(15,7))
sns.heatmap(dt.corr(),annot=True)
plt.title('HeatMap',fontsize=25)
plt.show()

# %% [markdown]
# ##### From above Heatmap:
#
# ##### Sales and Profit are Moderately Correlated.
# ##### Discount and Profit are Negatively Correlated
# ##### Quantity and Profit are less Moderately less Correlated.

# %% [markdown]
# ## Sub-Category Graph

# %%
plt.figure(figsize=(35,18))
sns.countplot(dt['Sub-Category'])
plt.title('Sub-Category of the Products',fontsize=35)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.barplot(x=dt['Sub-Category'], y=dt['Profit'])
plt.title('Sub-Category Profit',fontsize=30)
plt.show()

# %%
plt.figure(figsize = (15,7))
sns.lineplot('Discount', 'Profit', data = dt, color = 'b', label= 'Discount')
plt.title('Discount Linear Graph',fontsize=20)
plt.show()

# %% [markdown]
# ### Deep Analysis of Sales, Quantity, Discount, Profit

# %%
dt.hist(bins=60, figsize=(22,20))
#plt.title('Deep Analysis of Sales, Quantity, Discount, Profit')
plt.show()

# %%
plt.figure(figsize=(30,15))
sns.countplot(dt['State'])
plt.xticks(rotation=90)
plt.title('States',fontsize=35) #States where the product are supplied
plt.show()

# %%
plt.figure(figsize=(22,10))
sns.countplot(dt['Quantity'])
plt.title('Quantity',fontsize=25)
plt.show()

# %%
plt.figure(figsize=(22,10))
sns.countplot(dt['Discount'])
plt.xticks(rotation=90)
plt.title('Discount',fontsize=25)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(dt['Profit'])
plt.xticks(rotation=90)
plt.title('Profit',fontsize=25)
plt.show()

# %% [markdown]
# # Distribution of the Data

# %%
fig, axs = plt.subplots(ncols=2, nrows = 2, figsize = (15,10))
sns.distplot(dt['Sales'], color = 'red',  ax = axs[0][0])
sns.distplot(dt['Profit'], color = '#8B8000',  ax = axs[0][1])
sns.distplot(dt['Quantity'], color = 'darkgreen',  ax = axs[1][0])
sns.distplot(dt['Discount'], color = 'blue',  ax = axs[1][1])
axs[0][0].set_title('Sales Distribution', fontsize = 20)
axs[0][1].set_title('Profit Distribution', fontsize = 20)
axs[1][0].set_title('Quantity distribution', fontsize = 20)
axs[1][1].set_title('Discount Distribution', fontsize = 20)
plt.show()

# %% [markdown]
# # State wise Analysis

# %%
# sum the sales, profit, discount, quantity according to every state of region and also according to sub-categories sales
grouped=pd.DataFrame(dt.groupby(['Ship Mode','Segment','Category','Sub-Category','State','Region'])['Quantity','Discount','Sales','Profit'].sum().reset_index())
grouped
# Out:
#            Ship Mode      Segment    Category Sub-Category       State  \
# 0        First Class     Consumer   Furniture    Bookcases     Arizona
# 1        First Class     Consumer   Furniture    Bookcases  California
# 2        First Class     Consumer   Furniture    Bookcases    Colorado
# 3        First Class     Consumer   Furniture    Bookcases     Florida
# 4        First Class     Consumer   Furniture    Bookcases     Georgia
# ...              ...          ...         ...          ...         ...
# 2978  Standard Class  Home Office  Technology       Phones       Texas
# 2979  Standard Class  Home Office  Technology       Phones     Vermont
# 2980  Standard Class  Home Office  Technology       Phones    Virginia
# 2981  Standard Class  Home Office  Technology       Phones  Washington
# 2982  Standard Class  Home Office  Technology       Phones   Wisconsin
#
#        Region  Quantity  Discount     Sales    Profit
# 0        West         5      0.70   181.470 -320.5970
# ...

# %%
# sum, mean, min, max, count median, standard deviation, variance of each states of Profit
dt.groupby("State").Profit.agg(["sum","mean","min","max","count","median","std","var"])
# Out:
#                              sum        mean        min        max  count  \
# State
# Alabama                5786.8253   94.865989     0.0000  1459.2000     61
# Arizona               -3427.9246  -15.303235  -814.4832   211.4955    224
# Arkansas               4008.6871   66.811452     1.4190   843.1706     60
# California            76381.3871   38.171608  -325.5720  1906.4850   2001
# Colorado              -6527.8579  -35.867351 -3399.9800   247.9960    182
# Connecticut            3511.4918   42.823071   -15.5826   294.6710     82
# Delaware               9977.3748  103.930988   -48.7839  5039.9856     96
# District of Columbia   1059.5893  105.958930     4.4344   648.5624     10
# Florida               -3399.3017   -8.875461 -1811.0784   327.5922    383
# Georgia               16250.0433   88.315453     0.1134  3177.4750    184
# Idaho                   826.7231   39.367767     1.1151   259.5297     21
# Illinois             -12607.8870  -25.625787 -2929.4845   874.9875    492
# ...

# %%
sales_profit = dt.groupby("State")["Profit"].sum()
sales_profit
# Out:
# State
# Alabama                  5786.8253
# Arizona                 -3427.9246
# Arkansas                 4008.6871
# California              76381.3871
# Colorado                -6527.8579
# Connecticut              3511.4918
# Delaware                 9977.3748
# District of Columbia     1059.5893
# Florida                 -3399.3017
# Georgia                 16250.0433
# Idaho                     826.7231
# Illinois               -12607.8870
# Indiana                 18382.9363
# Iowa                     1183.8119
# Kansas                    836.4435
# Kentucky                11199.6966
# Louisiana                2196.1023
# Maine                     454.4862
# Maryland                 7031.1788
# Massachusetts            6785.5016
# Michigan                24463.1876
# Minnesota               10823.1874
# Mississippi              3172.9762
# Missouri                 6436.2105
# Montana                  1833.3285
# Nebraska                 2037.0942
# ...

# %%
# State wise Profit
plt.figure(figsize=(22,10))
sns.barplot(x=sales_profit.index, y=sales_profit.values)
plt.ylabel("Profit")
plt.xticks(rotation=90)
plt.title('State wise Profit',fontsize=25)
plt.show()

# %%
# State wise Sales
sales = dt.groupby("State")["Sales"].sum()
sales.plot.bar(figsize=(18,10))
plt.title('State wise Sales', fontsize = 25)
plt.show()

# %%
dt['Country'].value_counts()
# Out:
# United States    9994
# Name: Country, dtype: int64

# %%
dt1=dt['State'].value_counts()
dt1
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Virginia                 224
# Arizona                  224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Mississippi               53
# Utah                      53
# ...

# %%
dt1.plot(kind='bar',figsize=(18,10))
plt.ylabel('Frequency od deals/ Number of deals')
plt.xlabel('States')

plt.title('State wise Dealings', fontsize = 25)
plt.show()

# %% [markdown]
# ### Here is top 3 state where deals are Highest.
# #### 1. Califonia
# #### 2. New York
# #### 3. Texas
# ### Wyoming: Lowest Number of deal

# %%
dt['State'].value_counts().mean() #AVERAGE DEALS PER STATE
# Out:
# 203.9591836734694

# %% [markdown]
# #### Average number of deal per state is 204.

# %% [markdown]
# # Segment wise Analysis of Profit, Discount and Sell

# %%
dt['Segment'].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
dt_segment= dt.groupby(['Segment'])[['Sales', 'Discount', 'Profit']].mean()
dt_segment
# Out:
#                   Sales  Discount     Profit
# Segment
# Consumer     223.733644  0.158141  25.836873
# Corporate    233.823300  0.158228  30.456667
# Home Office  240.972041  0.147128  33.818664

# %%
#1. sales 2. Discount 3. Profit
dt_segment.plot.pie(subplots=True, 
                    autopct='%1.1f%%',
                    figsize=(25, 25),
                    startangle=90,     # start angle 90° (Africa)
                    shadow=True,
                    labels = dt_segment.index)
plt.title('Segment wise Analysis of Sales, Discount, Profit',fontsize=25)
plt.show()

# %% [markdown]
# #### Sales:
#
# #### *Consumer : 32%
#
# #### *Corporate : 33.5%
#
# #### *Home Office : 34.5%
#
# #### Discount :
#
# #### *Consumer : 15.8%
#
# #### *Corporate : 15.8%
#
# #### *Home Office : 14.7%
#
# #### Profit :
#
# #### *Consumer : 15.8%
#
# #### *Corporate : 15.8%
#
# #### *Home Office : 14.7%

# %% [markdown]
# # Statewise Analysis of Profit, Discount and Sales

# %%
dt['State'].value_counts().head(10)
# Out:
# California        2001
# New York          1128
# Texas              985
# Pennsylvania       587
# Washington         506
# Illinois           492
# Ohio               469
# Florida            383
# Michigan           255
# North Carolina     249
# Name: State, dtype: int64

# %%
dt_state= dt.groupby(['State'])[['Sales', 'Discount', 'Profit']].mean()
dt_state.head(10)
# Out:
#                            Sales  Discount      Profit
# State
# Alabama               319.846557  0.000000   94.865989
# Arizona               157.508933  0.303571  -15.303235
# Arkansas              194.635500  0.000000   66.811452
# California            228.729451  0.072764   38.171608
# Colorado              176.418231  0.316484  -35.867351
# Connecticut           163.223866  0.007317   42.823071
# Delaware              285.948635  0.006250  103.930988
# District of Columbia  286.502000  0.000000  105.958930
# Florida               233.612815  0.299347   -8.875461
# Georgia               266.825217  0.000000   88.315453

# %% [markdown]
# #### [1] Statewise Profit Analysis

# %%
dt_state1=dt_state.sort_values('Profit')
dt_state1[['Profit']].plot(kind = 'bar', figsize = (18,8))
plt.title('State wise Profit Analysis', fontsize = 25)
plt.ylabel('Profit per Sate')
plt.xlabel('States')
plt.show()

# %% [markdown]
# #### RESULT
#
# #### Vermont: Highest Profit
#
# #### Ohio: Lowest Profit

# %% [markdown]
# #### [2] Statewise Sales Analysis

# %%
dt_state['Sales'].plot(kind='pie',
                        figsize = (25,25),
                        autopct='%1.1f%%',
                        startangle=90,     # start angle 90° (Africa)
                        shadow=True)
plt.title('State wise Sales Analysis',fontsize=25)
plt.show()

# %% [markdown]
# #### Highest amount of sales= Wyoming(11.8%)
#
#
# #### Lowest amount of sales= South Dakota(0.8%)

# %% [markdown]
# #### [3] Statewise Discount Analysis

# %%
dt_state1['Discount'].plot(kind='bar',figsize=(22,8))
plt.title('State wise Analysis of Discount', fontsize=30)
plt.show()

# %% [markdown]
# ### Illinois at the top

# %% [markdown]
# ## City Wise Analysis of the Profit

# %%
dt_city= dt.groupby(['City'])[['Sales', 'Discount', 'Profit']].mean()
dt_city = dt_city.sort_values('Profit')
dt_city.head()
# Out:
#                  Sales  Discount      Profit
# City
# Bethlehem   337.926800  0.380000 -200.619160
# Champaign   151.960000  0.600000 -182.352000
# Oswego      107.326000  0.600000 -178.709200
# Round Rock  693.436114  0.274286 -169.061614
# Lancaster   215.031826  0.315217 -157.371052

# %%
#1.Low Profit
dt_city['Profit'].head(30).plot(kind='bar',figsize=(22,8),color = 'Purple')
plt.title('City wise Analysis of Profit based on Sales',fontsize=25)
plt.show()

# %%
#2. High Profit
dt_city['Profit'].tail(30).plot(kind='bar',figsize=(22,8),color = 'Purple')
plt.title('City wise Analysis of Profit based on Sales',fontsize=25)
plt.show()

# %% [markdown]
# #### 30 CITIES WHICH HAS PROFIT IN POSITIVE
#
# #### 30 CITIES WHICH HAS PROFIT IN NEGATIVE
#
# #### THE BALANCE IS PRETTY GOOD HERE!

# %% [markdown]
# ## QUANTITY WISE SALES, PROFIT AND DISCOUNT ANALYSIS

# %%
dt_quantity = dt.groupby(['Quantity'])[['Sales', 'Discount', 'Profit']].mean()
dt_quantity.head(10)
# Out:
#                Sales  Discount     Profit
# Quantity
# 1          59.234632  0.152959   8.276396
# 2         120.354488  0.154858  16.006831
# 3         175.201578  0.153329  23.667715
# 4         271.764059  0.157708  37.131310
# 5         337.936339  0.157146  40.257394
# 6         362.101960  0.166556  18.051517
# 7         395.888393  0.161980  56.579163
# 8         458.210802  0.171595  42.244342
# 9         498.083683  0.147946  68.557716
# 10        422.046737  0.190702  35.862404

# %%
#1. sales 2. Discount 3. Profit
dt_quantity.plot.pie(subplots=True, 
                    autopct='%1.1f%%',
                    figsize=(25, 25),
                     pctdistance=0.69,
                    startangle=90,     # start angle 90° (Africa)
                    shadow=True,
                    labels = dt_quantity.index)
plt.title('Quantity wise Analysis of Sales, Discount, Profit',fontsize=25)
plt.show()

# %% [markdown]
# #### 13 Number of Quantity is high for sales and Profit.

# %% [markdown]
# ## CATEGORY WISE SALES DISCOUNT AND PROFIT

# %%
dt_category = dt.groupby(['Category'])[['Sales', 'Discount', 'Profit']].mean()
dt_category
# Out:
#                       Sales  Discount     Profit
# Category
# Furniture        349.834887  0.173923   8.699327
# Office Supplies  119.324101  0.157285  20.327050
# Technology       452.709276  0.132323  78.752002

# %%
dt_category.plot.pie(subplots=True, 
                     figsize=(22, 30), 
                     autopct='%1.1f%%', 
                     labels = dt_category.index)
plt.title('Sales, Discount, Profit based on Multiple Product Categories',fontsize=25) #Sales, Discount, Profit based on multiple product categories
plt.show()

# %% [markdown]
# #### Maximun sales and Profit obtain in Technology.
#
# #### Minimun profit obtain in Furniture.

# %% [markdown]
# ## Sub-Category wise Sales, Profit and Discount

# %%
dt_sub_category = dt.groupby(['Sub-Category'])[['Sales', 'Discount', 'Profit']].mean()
dt_sub_category.head(10)
# Out:
#                     Sales  Discount      Profit
# Sub-Category
# Accessories    215.974604  0.078452   54.111788
# Appliances     230.755710  0.166524   38.922758
# Art             34.068834  0.074874    8.200737
# Binders        133.560560  0.372292   19.843574
# Bookcases      503.859633  0.211140  -15.230509
# Chairs         532.332420  0.170178   43.095894
# Copiers       2198.941618  0.161765  817.909190
# Envelopes       64.867724  0.080315   27.418019
# Fasteners       13.936774  0.082028    4.375660
# Furnishings     95.825668  0.138349   13.645918

# %% [markdown]
# #### [1] BASED ON THE SALES

# %%
plt.figure(figsize = (20,20))
plt.pie(dt_sub_category['Sales'], labels = dt_sub_category.index, autopct = '%1.1f%%')
plt.title('Sub-Category wise Sales Analysis', fontsize = 25)
plt.legend()
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# #### Copier have high sales than Machine.

# %% [markdown]
# #### [2] BASED ON THE DISCOUNT

# %%
plt.figure(figsize = (20,20))
plt.pie(dt_sub_category['Discount'], labels = dt_sub_category.index, autopct = '%1.1f%%')
plt.title('Sub-Category wise Discount Analysis', fontsize = 25)
plt.legend()
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# #### Binders , Machines and then tables have high Discount.

# %% [markdown]
# #### [3] BASED ON THE PROFIT

# %%
dt_sub_category.sort_values('Profit')[['Sales','Profit']].plot(kind='bar',
                                                              figsize= (20,10),
                                                              label=['Avg Sales Price($)','Profit($)'])
plt.title('Sales and Profit Graph',fontsize=25)
plt.show()

# %% [markdown]
# #### COPIER : HIGHEST PROFIT AS WELL AS SALES

# %% [markdown]
# ### REGION WISE ANALYSIS

# %%
dt_region = dt.groupby(['Region'])[['Sales', 'Discount', 'Profit']].mean()
dt_region
# Out:
#               Sales  Discount     Profit
# Region
# Central  215.772661  0.240353  17.092709
# East     238.336110  0.145365  32.135808
# South    241.803645  0.147253  28.857673
# West     226.493233  0.109335  33.849032

# %%
dt_region.plot.pie(subplots=True, 
                   figsize=(22, 25), 
                   autopct='%1.1f%%',
                   labels = dt_region.index)
plt.title('Pie Chart based on Region',fontsize=25)
plt.show()

# %% [markdown]
# #### HIGH SALES: South
# LOW SALES: Central
#
# #### HIGH DISCOUNT: Central
# LOW DISCOUNT: West
#
# #### HIGH PROFIT: West
# LOW PROFIT: Central

# %% [markdown]
# ## Sub-Category vs. Region

# %%
plt.figure(figsize=(20,10))
sns.countplot(x="Sub-Category", hue= "Region", data=dt)
plt.xticks(rotation="vertical",fontsize=15)
plt.title('Sub-Category vs Region Graph',fontsize=25)
plt.show()
#plt.plot()

# %% [markdown]
# ### SHIP MODE WISE ANALYSIS

# %%
dt['Ship Mode'].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
dt_shipmode = dt.groupby(['Ship Mode'])[['Sales', 'Discount', 'Profit']].mean()

# %%
dt_shipmode.plot.pie(subplots=True,
                     figsize=(18, 20), 
                     autopct='%1.1f%%', 
                     labels = dt_shipmode.index)
plt.title('Ship Mode',fontsize=25)
plt.show()

# %% [markdown]
# ### Profit and Discount is high in First Class
#
# ### Sales is high for Same day ship

# %% [markdown]
# # RESULT AND CONCLUSION
#
# Profit is more than that of sale but there are some areas where profit could be increased.
#
# Sales and Profit are Moderately Correlated.
# Sales is high for Same day ship.
#
# Sub-category: Copier: High Profit & sales.
#
# Sub-category: Binders , Machines and then tables have high Discount.
#
# Category: Maximun sales and Profit obtain in Technology.
#
# Category: Minimun profit obtain in Furniture.
#
# Quantity and Profit are less Moderately Correlated.
#
#
# Discount and Profit are Negatively Correlated.
#
# Profit and Discount is high in First Class
#
# ### State: Vermont: Highest Profit
#
# ### State: Ohio: Lowest Profit
#
#
#
# ## Here is top 3 city where deals are Highest.
#
# ### New York City
#
# ### Los Angeles
#
# ### Philadelphia
#
#
#
# ## Here is top 3 state where deals are Highest.
#
# ### Califonia
#
# ### New York
#
# ### Texas
#
#
# ## Wyoming : Lowest Number of deal,Highest amount of sales= Wyoming(11.8%)
#
#
# ## Lowest amount of sales= South Dakota(0.8%)
